# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhidanayak/NGCF-PyTorch/blob/master/NGCF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/
git_token= "iMfnKM1eP2ZRC1XQoQSecFVlngZfD52mCJXm"  #your git token

username= "nidhidanayak" #your username

repository= "NGCF-PyTorch"
# Out:
# /content/drive/MyDrive/Github

# %%
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'NGCF-PyTorch'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 148 (delta 32), reused 1 (delta 1), pack-reused 62
# Receiving objects: 100% (148/148), 14.05 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
# %cd /content/drive/MyDrive/Github/NGCF-PyTorch/NGCF
# Out:
# /content/drive/MyDrive/Github/NGCF-PyTorch/NGCF

# %%
# !ls -a
# Out:
# __init__.py  main.py  NGCF.py  utility

# %%
# !python main.py --dataset gowalla --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.0001 --save_flag 1 --pretrain 0 --batch_size 1024 --epoch 400 --verbose 1 --node_dropout [0.1] --mess_dropout [0.1,0.1,0.1]
# Out:
# n_users=3001, n_items=40981
# n_interactions=184919
# n_train=146740, n_test=38179, sparsity=0.00150
# already load adj matrix (43982, 43982) 0.053624629974365234
# Epoch 0 [9.4s]: train==[97.00076=96.99422 + 0.00651]
# Epoch 1 [8.8s]: train==[83.64454=83.63802 + 0.00652]
# Epoch 2 [8.8s]: train==[72.89114=72.88459 + 0.00653]
# Epoch 3 [8.8s]: train==[61.44781=61.44128 + 0.00654]
# Epoch 4 [8.9s]: train==[55.74214=55.73558 + 0.00655]
# Epoch 5 [8.8s]: train==[52.23523=52.22867 + 0.00656]
# Epoch 6 [8.8s]: train==[48.52762=48.52104 + 0.00657]
# Epoch 7 [9.5s]: train==[45.57510=45.56852 + 0.00658]
# Epoch 8 [9.2s]: train==[43.42444=43.41785 + 0.00659]
# Epoch 9 [8.8s + 35.9s]: train==[41.52399=41.51740 + 0.00660], recall=[0.00969, 0.03271], precision=[0.00556, 0.00384], hit=[0.09197, 0.24825], ndcg=[0.00867, 0.01611]
# save the weights in path:  model/9.pkl
# Epoch 10 [8.9s]: train==[40.43917=40.43256 + 0.00661]
# Epoch 11 [8.8s]: train==[39.39548=39.38885 + 0.00661]
# ...
